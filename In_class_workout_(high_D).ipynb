# %% [markdown]
# <a href="https://colab.research.google.com/github/smbillah/ist526/blob/main/In_class_workout_(high_D).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Essential Libraries

# %%
# python visualization libraries
import matplotlib.pyplot as plt
import matplotlib as mpl
# from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import plotly.express as px
# %matplotlib inline

import pandas as pd
import numpy as np

import plotly.express as px

# %% [markdown]
# # Load Data from GitHub

# %%
# ref: https://stackoverflow.com/questions/32400867/pandas-read-csv-from-url

# iris data
# url = 'https://raw.githubusercontent.com/smbillah/ist526/main/iris.csv'
url = 'https://raw.githubusercontent.com/smbillah/ist526/main/World%20Indicators_Migrated%20Data.csv'


#  sample data 
# url = 'https://raw.githubusercontent.com/smbillah/ist526/main/liver_dataset.csv'

# pandas call to read csv file 
df = pd.read_csv(url)

# quickly show the dataframe
df.head()
# Out:
#   Country/Region  Region       Year  Birth Rate  Business Tax Rate  \
# 0        Algeria  Africa  12/1/2000       0.020                NaN
# 1         Angola  Africa  12/1/2000       0.050                NaN
# 2          Benin  Africa  12/1/2000       0.043                NaN
# 3       Botswana  Africa  12/1/2000       0.027                NaN
# 4   Burkina Faso  Africa  12/1/2000       0.046                NaN
#
#    CO2 Emissions  Days to Start Business  Ease of Business  Energy Usage  \
# 0        87931.0                     NaN               NaN       26998.0
# 1         9542.0                     NaN               NaN        7499.0
# 2         1617.0                     NaN               NaN        1983.0
# 3         4276.0                     NaN               NaN        1836.0
# 4         1041.0                     NaN               NaN           NaN
#
#             GDP  ...  Life Expectancy Male  Mobile Phone Usage  \
# 0  5.479006e+10  ...                  67.0               0.003
# 1  9.129595e+09  ...                  44.0               0.002
# 2  2.359122e+09  ...                  53.0               0.008
# 3  5.788312e+09  ...                  49.0               0.127
# 4  2.610959e+09  ...                  49.0               0.002
#
#    Number of Records  Population 0-14  Population 15-64  Population 65+  \
# 0                  1            0.342             0.619           0.039
# 1                  1            0.476             0.499           0.025
# 2                  1            0.454             0.517           0.029
# 3                  1            0.383             0.587           0.029
# 4                  1            0.468             0.505           0.028
#
#    Population Total  Population Urban  Tourism Inbound  Tourism Outbound
# 0          31719449             0.599      102000000.0       193000000.0
# 1          13924930             0.324       34000000.0       146000000.0
# 2           6949366             0.383       77000000.0        50000000.0
# 3           1755375             0.532      227000000.0       209000000.0
# 4          11607944             0.178       23000000.0        30000000.0
#
# [5 rows x 27 columns]

# %%
# get column names
display(df.columns)
# Out:
# Index(['Country/Region', 'Region', 'Year', 'Birth Rate', 'Business Tax Rate',
#        'CO2 Emissions', 'Days to Start Business', 'Ease of Business',
#        'Energy Usage', 'GDP', 'Health Exp % GDP', 'Health Exp/Capita',
#        'Hours to do Tax', 'Infant Mortality Rate', 'Internet Usage',
#        'Lending Interest', 'Life Expectancy Female', 'Life Expectancy Male',
#        'Mobile Phone Usage', 'Number of Records', 'Population 0-14',
#        'Population 15-64', 'Population 65+', 'Population Total',
#        'Population Urban', 'Tourism Inbound', 'Tourism Outbound'],
#       dtype='object')

# %%
df = df.drop(['Business Tax Rate', 'Days to Start Business', 'Ease of Business', 'Hours to do Tax','Number of Records' ], axis= 1)

# %%
df.head().T
# Out:
#                                     0             1             2  \
# Country/Region                Algeria        Angola         Benin
# Region                         Africa        Africa        Africa
# Year                        12/1/2000     12/1/2000     12/1/2000
# Birth Rate                       0.02          0.05         0.043
# CO2 Emissions                 87931.0        9542.0        1617.0
# Energy Usage                  26998.0        7499.0        1983.0
# GDP                     54790058957.0  9129594819.0  2359122303.0
# Health Exp % GDP                0.035         0.034         0.043
# Health Exp/Capita                60.0          22.0          15.0
# Infant Mortality Rate           0.034         0.128          0.09
# Internet Usage                  0.005         0.001         0.002
# Lending Interest                  0.1         1.032           NaN
# Life Expectancy Female           71.0          47.0          57.0
# Life Expectancy Male             67.0          44.0          53.0
# Mobile Phone Usage              0.003         0.002         0.008
# Population 0-14                 0.342         0.476         0.454
# Population 15-64                0.619         0.499         0.517
# Population 65+                  0.039         0.025         0.029
# Population Total             31719449      13924930       6949366
# Population Urban                0.599         0.324         0.383
# Tourism Inbound           102000000.0    34000000.0    77000000.0
# Tourism Outbound          193000000.0   146000000.0    50000000.0
#
#                                    3             4
# Country/Region              Botswana  Burkina Faso
# Region                        Africa        Africa
# Year                       12/1/2000     12/1/2000
# Birth Rate                     0.027         0.046
# CO2 Emissions                 4276.0        1041.0
# Energy Usage                  1836.0           NaN
# GDP                     5788311645.0  2610959139.0
# Health Exp % GDP               0.047         0.051
# Health Exp/Capita              152.0          12.0
# Infant Mortality Rate          0.054         0.096
# Internet Usage                 0.029         0.001
# Lending Interest               0.155           NaN
# Life Expectancy Female          52.0          52.0
# Life Expectancy Male            49.0          49.0
# Mobile Phone Usage             0.127         0.002
# Population 0-14                0.383         0.468
# Population 15-64               0.587         0.505
# Population 65+                 0.029         0.028
# Population Total             1755375      11607944
# Population Urban               0.532         0.178
# Tourism Inbound          227000000.0    23000000.0
# Tourism Outbound         209000000.0    30000000.0

# %%
df = df.dropna(how='any', axis = 0)

# %% [markdown]
# # Use Seaborn Library
# http://seaborn.pydata.org/examples/index.html

# %%
# we already imported seaborn library in the first cell. Doing it again to emphasis.
import seaborn as sns

# %% [markdown]
# ## Correlation Matrix

# %%
df.corr()
# Out:
#                         Birth Rate  CO2 Emissions  Energy Usage       GDP  \
# Birth Rate                1.000000      -0.166121     -0.172086 -0.207485
# CO2 Emissions            -0.166121       1.000000      0.988503  0.756248
# Energy Usage             -0.172086       0.988503      1.000000  0.819246
# GDP                      -0.207485       0.756248      0.819246  1.000000
# Health Exp % GDP         -0.368148       0.101373      0.139158  0.326145
# Health Exp/Capita        -0.407281       0.148707      0.191941  0.425664
# Infant Mortality Rate     0.849554      -0.083911     -0.086105 -0.171950
# Internet Usage           -0.580250       0.079178      0.104380  0.286754
# Lending Interest          0.379220      -0.125527     -0.122287 -0.163730
# Life Expectancy Female   -0.816454       0.089099      0.096595  0.206064
# Life Expectancy Male     -0.736847       0.100463      0.102809  0.220374
# Mobile Phone Usage       -0.521683       0.002321      0.008211  0.122344
# Population 0-14           0.954446      -0.179133     -0.190368 -0.243112
# Population 15-64         -0.906539       0.202109      0.200705  0.166751
# Population 65+           -0.781835       0.108902      0.132530  0.275842
# Population Total         -0.029070       0.760542      0.730494  0.373659
# Population Urban         -0.491498       0.032755      0.053499  0.182338
# Tourism Inbound          -0.286548       0.670006      0.720959  0.841063
# Tourism Outbound         -0.295484       0.609331      0.665129  0.850607
#
#                         Health Exp % GDP  Health Exp/Capita  \
# Birth Rate                     -0.368148          -0.407281
# CO2 Emissions                   0.101373           0.148707
# Energy Usage                    0.139158           0.191941
# GDP                             0.326145           0.425664
# Health Exp % GDP                1.000000           0.596230
# Health Exp/Capita               0.596230           1.000000
# Infant Mortality Rate          -0.336288          -0.423296
# Internet Usage                  0.490852           0.781406
# Lending Interest               -0.056297          -0.320617
# Life Expectancy Female          0.356121           0.470933
# Life Expectancy Male            0.338847           0.522583
# Mobile Phone Usage              0.295003           0.458752
# Population 0-14                -0.418170          -0.475688
# Population 15-64                0.193411           0.311670
# Population 65+                  0.585266           0.556592
# Population Total               -0.119064          -0.059216
# Population Urban                0.338807           0.465025
# Tourism Inbound                 0.371688           0.503357
# Tourism Outbound                0.370777           0.560160
#
#                         Infant Mortality Rate  Internet Usage  \
# Birth Rate                           0.849554       -0.580250
# CO2 Emissions                       -0.083911        0.079178
# Energy Usage                        -0.086105        0.104380
# GDP                                 -0.171950        0.286754
# Health Exp % GDP                    -0.336288        0.490852
# Health Exp/Capita                   -0.423296        0.781406
# Infant Mortality Rate                1.000000       -0.586318
# Internet Usage                      -0.586318        1.000000
# Lending Interest                     0.463687       -0.398764
# Life Expectancy Female              -0.918651        0.604068
# Life Expectancy Male                -0.875174        0.615722
# Mobile Phone Usage                  -0.567218        0.719365
# Population 0-14                      0.787992       -0.656264
# Population 15-64                    -0.776063        0.543079
# Population 65+                      -0.612185        0.633169
# Population Total                     0.100138       -0.094971
# Population Urban                    -0.579013        0.540799
# Tourism Inbound                     -0.257024        0.357495
# Tourism Outbound                    -0.258803        0.439250
#
#                         Lending Interest  Life Expectancy Female  \
# Birth Rate                      0.379220               -0.816454
# CO2 Emissions                  -0.125527                0.089099
# Energy Usage                   -0.122287                0.096595
# GDP                            -0.163730                0.206064
# Health Exp % GDP               -0.056297                0.356121
# Health Exp/Capita              -0.320617                0.470933
# Infant Mortality Rate           0.463687               -0.918651
# Internet Usage                 -0.398764                0.604068
# Lending Interest                1.000000               -0.395502
# Life Expectancy Female         -0.395502                1.000000
# Life Expectancy Male           -0.442373                0.962687
# Mobile Phone Usage             -0.391965                0.520985
# Population 0-14                 0.359906               -0.757908
# Population 15-64               -0.358800                0.718867
# Population 65+                 -0.274520                0.621640
# Population Total               -0.052105               -0.054268
# Population Urban               -0.186619                0.577912
# Tourism Inbound                -0.246209                0.280224
# Tourism Outbound               -0.244589                0.291502
#
#                         Life Expectancy Male  Mobile Phone Usage  \
# Birth Rate                         -0.736847           -0.521683
# CO2 Emissions                       0.100463            0.002321
# Energy Usage                        0.102809            0.008211
# GDP                                 0.220374            0.122344
# Health Exp % GDP                    0.338847            0.295003
# Health Exp/Capita                   0.522583            0.458752
# Infant Mortality Rate              -0.875174           -0.567218
# Internet Usage                      0.615722            0.719365
# Lending Interest                   -0.442373           -0.391965
# Life Expectancy Female              0.962687            0.520985
# Life Expectancy Male                1.000000            0.501378
# Mobile Phone Usage                  0.501378            1.000000
# Population 0-14                    -0.671205           -0.598249
# Population 15-64                    0.658901            0.548716
# Population 65+                      0.523986            0.512895
# Population Total                   -0.021277           -0.118850
# Population Urban                    0.586762            0.443860
# Tourism Inbound                     0.302623            0.228740
# Tourism Outbound                    0.314470            0.245992
#
#                         Population 0-14  Population 15-64  Population 65+  \
# Birth Rate                     0.954446         -0.906539       -0.781835
# CO2 Emissions                 -0.179133          0.202109        0.108902
# Energy Usage                  -0.190368          0.200705        0.132530
# GDP                           -0.243112          0.166751        0.275842
# Health Exp % GDP              -0.418170          0.193411        0.585266
# Health Exp/Capita             -0.475688          0.311670        0.556592
# Infant Mortality Rate          0.787992         -0.776063       -0.612185
# Internet Usage                -0.656264          0.543079        0.633169
# Lending Interest               0.359906         -0.358800       -0.274520
# Life Expectancy Female        -0.757908          0.718867        0.621640
# Life Expectancy Male          -0.671205          0.658901        0.523986
# Mobile Phone Usage            -0.598249          0.548716        0.512895
# Population 0-14                1.000000         -0.908954       -0.867961
# Population 15-64              -0.908954          1.000000        0.581938
# Population 65+                -0.867961          0.581938        1.000000
# Population Total              -0.019332          0.081397       -0.059142
# Population Urban              -0.507921          0.480015        0.418746
# Tourism Inbound               -0.325618          0.238620        0.351200
# Tourism Outbound              -0.349363          0.241275        0.394235
#
#                         Population Total  Population Urban  Tourism Inbound  \
# Birth Rate                     -0.029070         -0.491498        -0.286548
# CO2 Emissions                   0.760542          0.032755         0.670006
# Energy Usage                    0.730494          0.053499         0.720959
# GDP                             0.373659          0.182338         0.841063
# Health Exp % GDP               -0.119064          0.338807         0.371688
# Health Exp/Capita              -0.059216          0.465025         0.503357
# Infant Mortality Rate           0.100138         -0.579013        -0.257024
# Internet Usage                 -0.094971          0.540799         0.357495
# Lending Interest               -0.052105         -0.186619        -0.246209
# Life Expectancy Female         -0.054268          0.577912         0.280224
# Life Expectancy Male           -0.021277          0.586762         0.302623
# Mobile Phone Usage             -0.118850          0.443860         0.228740
# Population 0-14                -0.019332         -0.507921        -0.325618
# Population 15-64                0.081397          0.480015         0.238620
# Population 65+                 -0.059142          0.418746         0.351200
# Population Total                1.000000         -0.152284         0.320279
# Population Urban               -0.152284          1.000000         0.218792
# Tourism Inbound                 0.320279          0.218792         1.000000
# Tourism Outbound                0.287981          0.286303         0.863920
#
#                         Tourism Outbound
# Birth Rate                     -0.295484
# CO2 Emissions                   0.609331
# Energy Usage                    0.665129
# GDP                             0.850607
# Health Exp % GDP                0.370777
# Health Exp/Capita               0.560160
# Infant Mortality Rate          -0.258803
# Internet Usage                  0.439250
# Lending Interest               -0.244589
# Life Expectancy Female          0.291502
# Life Expectancy Male            0.314470
# Mobile Phone Usage              0.245992
# Population 0-14                -0.349363
# Population 15-64                0.241275
# Population 65+                  0.394235
# Population Total                0.287981
# Population Urban                0.286303
# Tourism Inbound                 0.863920
# Tourism Outbound                1.000000

# %% [markdown]
# ## Heatmap with Correlation Matrix

# %%
# 'cmap' stands for color map
sns.heatmap(df.corr(), annot = False) 
plt.show()

# %% [markdown]
# ## Showing missing value

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %% [markdown]
# # Use Plotly Express Library: More Powerful than Seaborn

# %% [markdown]
# ## Scatter plot/ Bubble plot

# %%
import plotly.express as px

# basic scatter plot
# fig = px.scatter(df, y="GDP", x="Infant Mortality Rate", log_y=True, color='Country/Region')
fig = px.scatter(df, y="GDP", x="Infant Mortality Rate", log_y=True, color='Region', size = 'Birth Rate')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="be50e6f5-4ff9-4434-842e-944e0a66c403" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be50e6f5-4ff9-4434-842e-944e0a66c403")) {                    Plotly.newPlot(                        "be50e6f5-4ff9-4434-842e-944e0a66c403",                        [{"hovertemplate":"Region=Africa<br>Infant Mortality Rate=%{x}<br>GDP=%{y}<br>Birth Rate=%{marker.size}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","size":[0.02,0.05,0.027,0.041,0.039,0.025,0.044,0.034,0.039,0.022,0.022,0.044,0.032,0.043,0.024,0.042,0.045,0.019,0.05,0.027,0.041,0.039,0.025,0.043,0.034,0.039,0.022,0.021,0.045,0.031,0.043,0.024,0.042,0.045,0.019,0.05,0.026,0.041,0.039,0.024,0.042,0.033,0.039,0.023,0.021,0.045,0.031,0.043,0.024,0.042,0.045,0.02,0.05,0.026,0.041,0.039,0.024,0.041,0.033,0.039,0.023,0.021,0.045,0.03,0.043,0.023,0.042,0.045,0.02,0.05,0.026,0.041,0.039,0.039,0.029,0.024,0.04,0.033,0.044,0.039,0.023,0.016,0.02,0.044,0.03,0.038,0.017,0.023,0.032,0.042,0.044,0.015,0.019,0.02,0.021,0.023,0.023,0.024,0.025,0.029,0.029,0.032,0.033,0.038,0.039,0.039,0.039,0.039,0.04,0.042,0.042,0.044,0.044,0.044,0.049,0.014,0.017,0.022,0.023,0.023,0.024,0.025,0.029,0.031,0.038,0.038,0.038,0.039,0.039,0.04,0.042,0.042,0.043,0.044,0.044,0.046,0.049,0.014,0.018,0.022,0.023,0.023,0.024,0.025,0.028,0.028,0.029,0.031,0.037,0.038,0.038,0.039,0.039,0.04,0.042,0.042,0.043,0.044,0.044,0.045,0.048,0.022,0.022,0.024,0.024,0.025,0.028,0.036,0.038,0.041,0.042,0.042,0.043,0.045,0.048,0.022,0.022,0.024,0.024,0.025,0.027,0.037,0.041,0.041,0.042,0.043,0.044,0.047,0.022,0.022,0.024,0.024,0.025,0.027,0.037,0.041,0.041,0.042,0.043,0.044,0.046],"sizemode":"area","sizeref":0.000125,"symbol":"circle"},"mode":"markers","name":"Africa","showlegend":true,"x":[0.034,0.128,0.054,0.093,0.077,0.036,0.09,0.056,0.069,0.024,0.043,0.114,0.049,0.113,0.052,0.08,0.1,0.033,0.127,0.054,0.09,0.075,0.034,0.087,0.055,0.068,0.024,0.041,0.109,0.049,0.11,0.053,0.076,0.095,0.032,0.126,0.054,0.087,0.073,0.031,0.083,0.054,0.066,0.023,0.04,0.104,0.049,0.106,0.053,0.071,0.091,0.031,0.125,0.051,0.084,0.07,0.029,0.079,0.053,0.065,0.022,0.038,0.099,0.049,0.103,0.053,0.066,0.086,0.03,0.123,0.046,0.081,0.071,0.066,0.073,0.027,0.074,0.052,0.058,0.063,0.021,0.014,0.037,0.095,0.048,0.05,0.012,0.052,0.082,0.061,0.081,0.014,0.012,0.035,0.029,0.051,0.02,0.026,0.043,0.046,0.071,0.081,0.05,0.048,0.062,0.061,0.07,0.07,0.078,0.097,0.057,0.076,0.091,0.057,0.122,0.014,0.012,0.028,0.05,0.019,0.024,0.043,0.044,0.076,0.059,0.065,0.046,0.057,0.069,0.076,0.094,0.054,0.087,0.073,0.056,0.102,0.12,0.014,0.012,0.047,0.026,0.017,0.023,0.043,0.082,0.042,0.067,0.075,0.061,0.058,0.044,0.053,0.068,0.073,0.091,0.05,0.082,0.07,0.055,0.1,0.117,0.046,0.016,0.021,0.025,0.043,0.041,0.057,0.056,0.047,0.078,0.088,0.067,0.097,0.115,0.04,0.015,0.021,0.024,0.041,0.039,0.054,0.074,0.044,0.085,0.065,0.095,0.112,0.035,0.014,0.04,0.02,0.024,0.038,0.052,0.072,0.041,0.082,0.064,0.092,0.11],"xaxis":"x","y":[54790058957.0,9129594819.0,5788311645.0,9287367569.0,3219910666.0,99838540997.0,8091384891.0,5067865503.0,12705350153.0,33896600871.0,37020609825.0,4310090791.0,3908645566.0,46385996027.0,133000000000.0,10185786171.0,3253551750.0,54744716706.0,8936079253.0,5489646903.0,9633109257.0,2794259756.0,97632008051.0,8080496318.0,4712849280.0,12985991723.0,28420321952.0,37724674865.0,4075049537.0,3546791603.0,44138014092.0,118000000000.0,10383560998.0,3653822712.0,56760288962.0,12497346043.0,5438856515.0,10879778328.0,3019993723.0,87850680573.0,7707034813.0,4931503836.0,13147736954.0,19842519685.0,40416114690.0,4201332885.0,3361236321.0,59116868250.0,111000000000.0,10805600069.0,3711284087.0,67863832648.0,14188949240.0,7511538765.0,13621809574.0,3495868725.0,82923680622 ...

# %% [markdown]
# ## Scatter plot matrix

# %%
import plotly.express as px

# select features/columns 
# features = ['petal.length', 'sepal.length', 'petal.width', 'sepal.width']

fig = px.scatter_matrix(
    df,
    # dimensions=features,
    # color="variety"
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7b06bbdd-a234-4fd7-b56f-3ce4623b5a73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b06bbdd-a234-4fd7-b56f-3ce4623b5a73")) {                    Plotly.newPlot(                        "7b06bbdd-a234-4fd7-b56f-3ce4623b5a73",                        [{"dimensions":[{"axis":{"matches":true},"label":"Country/Region","values":["Algeria","Angola","Botswana","Cameroon","Congo (Brazzaville)","Egypt","Ethiopia","Gabon","Kenya","Libya","Morocco","Mozambique","Namibia","Nigeria","South Africa","Tanzania","Zambia","Armenia","Azerbaijan","Bangladesh","China","Georgia","India","Indonesia","Japan","South Korea","Kyrgyzstan","Malaysia","Mongolia","Nepal","Philippines","Singapore","Sri Lanka","Thailand","Albania","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Latvia","Lithuania","North Macedonia","Malta","Moldova","Netherlands","Norway","Poland","Romania","Russia","Slovakia","Slovenia","Spain","Sweden","Switzerland","Ukraine","United Kingdom","Bahrain","Israel","Jordan","Kuwait","Oman","Syria","United Arab Emirates","Yemen","Australia","New Zealand","Argentina","Bolivia","Brazil","Canada","Chile","Colombia","Costa Rica","Dominican Republic","Ecuador","El Salvador","Guatemala","Haiti","Honduras","Jamaica","Mexico","Nicaragua","Panama","Paraguay","Peru","Trinidad and Tobago","United States","Uruguay","Venezuela","Algeria","Angola","Botswana","Cameroon","Congo (Brazzaville)","Egypt","Ethiopia","Gabon","Kenya","Libya","Morocco","Mozambique","Namibia","Nigeria","South Africa","Tanzania","Zambia","Armenia","Azerbaijan","Bangladesh","Brunei","China","Georgia","India","Indonesia","Japan","South Korea","Kyrgyzstan","Malaysia","Mongolia","Nepal","Philippines","Singapore","Sri Lanka","Thailand","Albania","Belarus","Belgium","Bulgaria","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Latvia","Lithuania","North Macedonia","Malta","Moldova","Netherlands","Norway","Poland","Romania","Russia","Slovakia","Slovenia","Spain","Sweden","Switzerland","Ukraine","United Kingdom","Bahrain","Israel","Jordan","Kuwait","Oman","Syria","United Arab Emirates","Yemen","Australia","New Zealand","Argentina","Bolivia","Brazil","Canada","Chile","Colombia","Costa Rica","Dominican Republic","Ecuador","Guatemala","Haiti","Honduras","Jamaica","Mexico","Nicaragua","Panama","Paraguay","Peru","Trinidad and Tobago","United States","Uruguay","Venezuela","Algeria","Angola","Botswana","Cameroon","Congo (Brazzaville)","Egypt","Ethiopia","Gabon","Kenya","Libya","Morocco","Mozambique","Namibia","Nigeria","South Africa","Tanzania","Zambia","Armenia","Azerbaijan","Bangladesh","Brunei","China","Georgia","India","Indonesia","Japan","South Korea","Kyrgyzstan","Malaysia","Mongolia","Nepal","Philippines","Singapore","Sri Lanka","Tajikistan","Thailand","Albania","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Latvia","Lithuania","North Macedonia","Malta","Moldova","Netherlands","Norway","Poland","Romania","Russia","Slovakia","Slovenia","Spain","Sweden","Switzerland","Ukraine","United Kingdom","Bahrain","Israel","Jordan","Kuwait","Lebanon","Oman","Syria","Yemen","New Zealand","Argentina","Bolivia","Brazil","Canada","Chile","Colombia","Costa Rica","Dominican Republic","Ecuador","Guatemala","Haiti","Honduras","Jamaica","Mexico","Nicaragua","Panama","Paraguay","Peru","Trinidad and Tobago","United States","Uruguay","Venezuela","Algeria","Angola","Botsw ...

# %% [markdown]
# ## Heatmap/Correlation Plot: Plotly

# %%
## So, if we pass the correlation function, it will display the heatmap

## display(df.corr())
fig = px.imshow(df.corr(), text_auto=True, aspect="auto")

## to disable, text, set 'text_auto=False"
# fig = px.imshow(df.corr(), text_auto=False, aspect="auto")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1605549d-640d-4175-8617-f8f9ab1e6c5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1605549d-640d-4175-8617-f8f9ab1e6c5e")) {                    Plotly.newPlot(                        "1605549d-640d-4175-8617-f8f9ab1e6c5e",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Birth Rate","CO2 Emissions","Energy Usage","GDP","Health Exp % GDP","Health Exp/Capita","Infant Mortality Rate","Internet Usage","Lending Interest","Life Expectancy Female","Life Expectancy Male","Mobile Phone Usage","Population 0-14","Population 15-64","Population 65+","Population Total","Population Urban","Tourism Inbound","Tourism Outbound"],"y":["Birth Rate","CO2 Emissions","Energy Usage","GDP","Health Exp % GDP","Health Exp/Capita","Infant Mortality Rate","Internet Usage","Lending Interest","Life Expectancy Female","Life Expectancy Male","Mobile Phone Usage","Population 0-14","Population 15-64","Population 65+","Population Total","Population Urban","Tourism Inbound","Tourism Outbound"],"z":[[1.0,-0.16612110830479268,-0.17208601789082068,-0.20748528103245778,-0.36814849204006206,-0.40728075111804424,0.8495535700205418,-0.5802496635734415,0.3792202280360081,-0.816453739752891,-0.7368473864365122,-0.521682667040082,0.9544460644101866,-0.9065391451590392,-0.781834867034308,-0.029069693809284015,-0.4914976313666112,-0.2865483277365905,-0.29548433002493313],[-0.16612110830479268,1.0,0.9885030044480068,0.7562479878522259,0.10137317492418689,0.1487066763524384,-0.08391090947823847,0.0791784273563994,-0.12552692414380776,0.08909944702002491,0.1004631046860855,0.002320971401460455,-0.1791330393894946,0.20210881484660628,0.10890240945122007,0.7605419464906156,0.03275535051049543,0.670005915289643,0.6093311812139235],[-0.17208601789082068,0.9885030044480068,1.0,0.819246017851036,0.1391583614909741,0.19194057684085697,-0.08610490326586887,0.10438014804358625,-0.1222869966894166,0.09659510786342976,0.10280913428115362,0.008211405907881213,-0.19036820704544055,0.20070470361342058,0.13253023192614263,0.7304936634255789,0.053499446818827776,0.720958940725743,0.6651292843232095],[-0.20748528103245778,0.7562479878522259,0.819246017851036,1.0,0.32614531972078,0.4256642527635168,-0.1719503575242391,0.28675394231666407,-0.16373029567053388,0.2060642679821266,0.22037443389432249,0.12234407711505199,-0.2431116888880887,0.16675101218264451,0.27584186665804816,0.37365860394979944,0.1823380413014323,0.8410633233749708,0.8506070351681967],[-0.36814849204006206,0.10137317492418689,0.1391583614909741,0.32614531972078,1.0,0.5962300893698469,-0.3362880972021343,0.49085178716776623,-0.05629664700487852,0.356121188098959,0.3388465241994171,0.29500300104485483,-0.41816971238859907,0.19341082575338217,0.5852664966158927,-0.11906394083466638,0.3388067421441315,0.37168803981462795,0.3707765474118499],[-0.40728075111804424,0.1487066763524384,0.19194057684085697,0.4256642527635168,0.5962300893698469,1.0,-0.4232958932054706,0.7814061581035114,-0.3206173711359362,0.4709332093328146,0.5225825622340166,0.4587520350112962,-0.47568814253187924,0.31167041348353114,0.5565924780996729,-0.059216433247855325,0.4650254560760412,0.5033574220970718,0.5601603594766457],[0.8495535700205418,-0.08391090947823847,-0.08610490326586887,-0.1719503575242391,-0.3362880972021343,-0.4232958932054706,1.0,-0.5863184915382521,0.4636867559574005,-0.9186506161934491,-0.8751744219513387,-0.5672181542633312,0.7879922182587497,-0.7760634390054945,-0.6121853505222596,0.10013774665018081,-0.5790134915768674,-0.2570241615524517,-0.25880267512108246],[-0.5802496635734415,0.0791784273563994,0.10438014804358625,0.28675394231666407,0.49085178716776623,0.7814061581035114,-0.5863184915382521,1.0,-0.3987 ...

# %% [markdown]
# # Parallel Coordinate: Plotly Express

# %%
import plotly.express as px
# no color label
fig = px.parallel_coordinates(df)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ed8a3d27-c57d-44f8-a034-f6f4382fe962" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed8a3d27-c57d-44f8-a034-f6f4382fe962")) {                    Plotly.newPlot(                        "ed8a3d27-c57d-44f8-a034-f6f4382fe962",                        [{"dimensions":[{"label":"Birth Rate","values":[0.02,0.05,0.027,0.041,0.039,0.025,0.044,0.034,0.039,0.022,0.022,0.044,0.032,0.043,0.024,0.042,0.045,0.013,0.015,0.027,0.014,0.012,0.026,0.022,0.009,0.013,0.02,0.023,0.019,0.033,0.03,0.012,0.018,0.015,0.019,0.009,0.011,0.01,0.009,0.01,0.013,0.009,0.013,0.01,0.011,0.013,0.009,0.01,0.01,0.014,0.014,0.01,0.009,0.01,0.013,0.012,0.012,0.013,0.013,0.01,0.01,0.009,0.01,0.009,0.01,0.01,0.011,0.008,0.012,0.021,0.022,0.031,0.024,0.024,0.03,0.017,0.039,0.013,0.015,0.019,0.031,0.021,0.011,0.017,0.023,0.02,0.025,0.025,0.025,0.037,0.031,0.032,0.021,0.024,0.028,0.024,0.028,0.024,0.015,0.014,0.016,0.024,0.019,0.05,0.027,0.041,0.039,0.025,0.043,0.034,0.039,0.022,0.021,0.045,0.031,0.043,0.024,0.042,0.045,0.013,0.014,0.026,0.022,0.013,0.012,0.025,0.021,0.009,0.012,0.02,0.022,0.019,0.032,0.029,0.012,0.018,0.014,0.018,0.009,0.011,0.009,0.009,0.013,0.009,0.012,0.009,0.011,0.013,0.009,0.009,0.01,0.014,0.015,0.009,0.008,0.009,0.012,0.01,0.012,0.013,0.013,0.01,0.01,0.009,0.01,0.009,0.01,0.01,0.01,0.008,0.011,0.021,0.021,0.031,0.023,0.023,0.03,0.016,0.039,0.013,0.014,0.018,0.031,0.02,0.011,0.016,0.023,0.02,0.025,0.025,0.036,0.031,0.031,0.019,0.024,0.027,0.024,0.028,0.024,0.015,0.014,0.016,0.023,0.019,0.05,0.026,0.041,0.039,0.024,0.042,0.033,0.039,0.023,0.021,0.045,0.031,0.043,0.024,0.042,0.045,0.013,0.014,0.026,0.022,0.013,0.012,0.025,0.021,0.009,0.01,0.019,0.021,0.019,0.031,0.029,0.011,0.019,0.029,0.014,0.017,0.009,0.011,0.009,0.009,0.009,0.013,0.009,0.012,0.01,0.011,0.013,0.009,0.009,0.01,0.014,0.015,0.009,0.009,0.009,0.012,0.01,0.012,0.013,0.012,0.009,0.01,0.01,0.01,0.009,0.01,0.011,0.01,0.009,0.011,0.02,0.021,0.031,0.022,0.017,0.023,0.029,0.038,0.014,0.018,0.03,0.02,0.011,0.016,0.022,0.019,0.024,0.025,0.036,0.03,0.03,0.018,0.023,0.027,0.023,0.027,0.023,0.015,0.014,0.016,0.023,0.02,0.05,0.026,0.041,0.039,0.024,0.041,0.033,0.039,0.023,0.021,0.045,0.03,0.043,0.023,0.042,0.045,0.014,0.025,0.021,0.012,0.012,0.024,0.021,0.009,0.01,0.021,0.02,0.03,0.028,0.011,0.019,0.029,0.013,0.016,0.011,0.009,0.009,0.009,0.012,0.009,0.01,0.011,0.013,0.01,0.009,0.014,0.015,0.009,0.009,0.009,0.012,0.01,0.012,0.012,0.012,0.009,0.01,0.01,0.01,0.009,0.011,0.01,0.009,0.012,0.02,0.022,0.03,0.022,0.016,0.022,0.028,0.037,0.014,0.018,0.03,0.019,0.011,0.016,0.022,0.018,0.024,0.024,0.035,0.03,0.03,0.017,0.023,0.026,0.023,0.027,0.023,0.015,0.014,0.016,0.023,0.02,0.05,0.026,0.041,0.039,0.039,0.029,0.024,0.04,0.033,0.044,0.039,0.023,0.016,0.02,0.044,0.03,0.038,0.017,0.023,0.032,0.042,0.044,0.014,0.024,0.02,0.012,0.012,0.024,0.021,0.009,0.01,0.022,0.019,0.021,0.029,0.028,0.028,0.01,0.019,0.029,0.013,0.015,0.011,0.008,0.009,0.009,0.012,0.01,0.01,0.011,0.013,0.009,0.015,0.015,0.01,0.009,0.009,0.012,0.01,0.012,0.012,0.012,0.009,0.01,0.01,0.01,0.009,0.011,0.01,0.009,0.012,0.019,0.018,0.021,0.03,0.021,0.015,0.022,0.016,0.028,0.036,0.024,0.014,0.03,0.035,0.029,0.03,0.019,0.018,0.015,0.013,0.027,0.029,0.019,0.015,0.019,0.02,0.021,0.023,0.023,0.024,0.025,0.029,0.029,0.032,0.033,0.038,0.039,0.039,0.039,0.039,0.04,0.042,0.042,0.044,0.044,0.044,0.049,0.014,0.017,0.022,0.023,0.023,0.024,0.025,0.029,0.031,0.038,0.038,0.038,0.039,0.039,0.04,0.042,0.042,0.043,0.044,0.044,0.046,0.049,0.014,0.018,0.022,0.023,0.023,0.024,0.025,0.028,0.028,0.029,0.031,0.037,0.038,0.038,0.039,0.039,0.04,0.042,0.042,0.043,0.044,0.044,0.045,0.048,0.022,0.022,0.024,0.024,0.025,0.028,0.036,0.038,0.041,0.042,0.042,0.043,0.045,0.048,0.022,0.022, ...

# %% [markdown]
# # Intro to Python and Pandas Dataframe

# %% [markdown]
# ## Create a Dummy Data Frame

# %%
# Let's create a dummy data frame with string data
df_dummy = pd.DataFrame({'col1':[1,2,3], 'col2':['a', 'b', 'c'], 'col3':['jack', 'joe', 'jane']})
display(df_dummy.head())
# Out:
#    col1 col2  col3
# 0     1    a  jack
# 1     2    b   joe
# 2     3    c  jane

# %% [markdown]
# ## Convering string/char columns to categorical

# %%
# convering string/char columns to categorical
df_dummy['col2'] = pd.Categorical(df_dummy['col2'])
display(df_dummy.head())

df_dummy['col3'] = pd.Categorical(df_dummy['col3'])
display(df_dummy.head())
# Out:
#    col1 col2  col3
# 0     1    a  jack
# 1     2    b   joe
# 2     3    c  jane
#    col1 col2  col3
# 0     1    a  jack
# 1     2    b   joe
# 2     3    c  jane

# %% [markdown]
# Although the above datafram looks identifical, panda internally considers these columns as categorical variable. Many algorithms work with categorical data without any issue. However, if an algorithm expects numeric data, panda could provide numeric codes for these columns. See below.

# %%
df_dummy['col2_code'] = df_dummy.col2.cat.codes
df_dummy['col3_code'] = df_dummy.col3.cat.codes
display(df_dummy.head())
# Out:
#    col1 col2  col3  col2_code  col3_code
# 0     1    a  jack          0          0
# 1     2    b   joe          1          2
# 2     3    c  jane          2          1

# %% [markdown]
# So, you can now remove 'col2' and 'col3', and work with 'col2_code' and 'col3_code' instead.

# %% [markdown]
# ## Remove a column or a set of column

# %%
df_dummy = df_dummy.drop(['col2', 'col3'], axis= 1)
display(df_dummy.head())
# Out:
#    col1  col2_code  col3_code
# 0     1          0          0
# 1     2          1          2
# 2     3          2          1

# %% [markdown]
# ## Select columns by index

# %%
df_dummy.iloc[0:2]
# Out:
#    col1  col2_code  col3_code
# 0     1          0          0
# 1     2          1          2

# %% [markdown]
# # High Dimensional Data Reduction

# %% [markdown]
# ## PCA Demo: Plotly Express

# %%
# drop non-integer columns
df = df.drop(['Country/Region', 'Region', 'Year'], axis = 1);

# %%
import plotly.express as px
from sklearn.decomposition import PCA

## create PCA model
pca_model = PCA(n_components=2)
reduced_dims_pca = pca_model.fit_transform(df)

## note that parameters 'x' and 'y' indciate axis reference in 'reduced_dims' data
fig1 = px.scatter(reduced_dims_pca, x=0, y=1 )

## if you dataset has no label, remove 'color' parameter
# fig1 = px.scatter(reduced_dims_pca, x=0, y=1)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a835a921-b387-4fc5-9711-c0c55ade0170" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a835a921-b387-4fc5-9711-c0c55ade0170")) {                    Plotly.newPlot(                        "a835a921-b387-4fc5-9711-c0c55ade0170",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[-239824925579.5236,-285482335483.9527,-288820932829.8779,-285322741801.71375,-291392543883.3258,-194728970536.84183,-286519543888.5561,-289542737996.73517,-281902557290.6815,-260713659977.24414,-257569810595.6571,-290301275564.8273,-290701957913.6499,-248223319981.43808,-161567885772.50632,-284420865039.99115,-291357981425.30383,-292700441082.1217,-289338733152.25214,-247487074656.02527,905576710817.1511,-291553430037.76733,182413285524.49573,-129550771747.46352,4435435405820.423,267492662780.32822,-293242832798.8422,-200753152760.06543,-293475140223.9165,-289116028677.4067,-213554384022.1206,-198693752178.00076,-278276196585.44794,-171501561175.9164,-290920042818.8027,-281872996273.6086,-61480420796.244026,-289104221259.5671,-281690477387.3527,-273064576064.06595,-285273908270.47955,-235771202464.14017,-134547619587.97157,-288929181632.6658,-172582642541.3786,1035882476671.023,1596014203680.08,-170494442042.42545,-248179689472.97632,-285908163211.5633,-197232075200.73138,805729148447.4689,-286776148767.2113,-283173190763.21045,-291024924851.2437,-290646918512.3344,-293323184933.3124,90590407752.1203,-126556604554.9393,-123538637779.58342,-257303119707.86926,-34517447534.20118,-265884023399.0949,-274620551449.7933,285708598231.4618,-47502454465.89165,-38481186720.42785,-263343471846.0196,1195991339015.52,-285538537724.8178,-169545159673.81403,-286143345127.8843,-256866399684.7772,-274737109219.6484,-275272223161.79407,-190582669660.04242,-284975466725.9905,120555182955.51514,-242573004256.36154,49439200022.09932,-286213692977.39636,350391693769.61536,444588887037.1477,-215271705586.79385,-194708976160.0006,-278648939524.31464,-270587952485.1821,-276278900614.2652,-281473797439.57227,-275317362710.5916,-290945806763.82135,-287503614988.1904,-285588316035.12036,389471457715.64545,-289503569607.5173,-282985301538.39935,-286415281506.70874,-243922129794.27182,-286454019442.6752,10006462752956.152,-271780359965.631,-177602865032.33133,-239870272001.3381,-285676478792.2226,-289119438080.95856,-284976992229.7754,-291817835165.52673,-196939789872.78458,-286530610344.1547,-289897481186.51227,-281621345309.9521,-266188624033.08047,-256858734555.73752,-290536287446.1336,-291063280736.5495,-250468802780.34006,-176570425794.98724,-284220934790.47595,-290957628273.66534,-292493261562.8877,-288904060195.73474,-247625451953.89703,-289006343993.0555,1025589372230.596,-291391076673.2951,199416164395.11597,-134545493431.62854,3865414526604.903,238493757903.88348,-293087385394.12054,-201734194327.69223,-293343946092.4,-288603332917.95154,-218320428014.84387,-205228131546.9046,-278860914733.9897,-178504852241.08844,-290515433849.23157,-282251862587.2552,-62450360006.116135,-280725726618.85443,-271524633516.63556,-284908724519.6449,-230201379127.65237,-134542690103.93375,-288364746136.88727,-169581163780.02197,1045880667973.6752,1585997481862.8735,-164499123814.89105,-241839769277.10815,-286683417171.4501,-189558541707.91315,825699400269.1454,-286296643945.6199,-282448614222.034,-291175169450.6347,-290687156634.5916,-293130916931.3522,106581868558.29245,-123559896882.30292,-104547773228.32878,-254022124959.9597,12499153064.740582,-264287592183.02853,-274100588840.72885,314724154483.42883,-67507565111.02213,-31481796133.325466,-256593340109.7828,119 ...

# %% [markdown]
# # MDS Demo: Plotly Express

# %%
from sklearn.manifold import MDS

## 2. create a model

# Be very careful about 'dissimilarity' parameter
#mds_model = MDS(n_components=2, dissimilarity='precomputed')
mds_model = MDS(n_components=2, dissimilarity='euclidean')

# run MDS
reduced_dims_mds = mds_model.fit_transform(df)

## note that parameters 'x' and 'y' indciate axis reference in 'reduced_dims' data
fig2 = px.scatter(reduced_dims_mds, x=0, y=1)

# show it
fig2.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning:
#
# The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ceaa710bc40d> in <cell line: 10>()
#       8
#       9 # run MDS
# ---> 10 reduced_dims_mds = mds_model.fit_transform(df)
#      11
#      12 ## note that parameters 'x' and 'y' indciate axis reference in 'reduced_dims' data
#
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_mds.py in fit_transform(self, X, y, init)
#     611             self.dissimilarity_matrix_ = euclidean_distances(X)
#     612
# --> 613         self.embedding_, self.stress_, self.n_iter_ = smacof(
#     614             self.dissimilarity_matrix_,
#     615             metric=self.metric,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_mds.py in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter, normalized_stress)
#     326     if effective_n_jobs(n_jobs) == 1:
#     327         for it in range(n_init):
# --> 328             pos, stress, n_iter_ = _smacof_single(
#     329                 dissimilarities,
#     330                 metric=metric,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_mds.py in _smacof_single(dissimilarities, metric, n_components, init, max_iter, verbose, eps, random_state, normalized_stress)
#     127     for it in range(max_iter):
#     128         # Compute distance and monotonic regression
# --> 129         dis = euclidean_distances(X)
#     130
#     131         if metric:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     326             )
#     327
# --> 328     return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     329
#     330
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     368         # if dtype is already float64, no need to chunk and upcast
#     369         distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
# --> 370         distances += XX
#     371         distances += YY
#     372     np.maximum(distances, 0, out=distances)
#
# KeyboardInterrupt:

# %% [markdown]
# # t-SNE Demo: Plotly Express

# %%
from sklearn.manifold import TSNE

## 2. create a model

# Be very careful about 'perplexity' and 'metric' parameters
#tsne_model = TSNE(n_components=2, random_state=0, metric='precomputed', perplexity = 20 ) # 
tsne_model = TSNE(n_components=2, random_state=0, metric='euclidean', perplexity = 50) 


# run t-SNE
reduced_dims_tsne = tsne_model.fit_transform(df)

## note that parameters 'x' and 'y' indciate axis reference in 'reduced_dims' data
fig3 = px.scatter(reduced_dims_tsne, x=0, y=1)

## if you dataset has no label, remove 'color' parameter
# fig3 = px.scatter(reduced_dims_tsne, x=0, y=1)

# show it
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="19b2525d-e970-4c1e-93d6-f9b414aad203" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19b2525d-e970-4c1e-93d6-f9b414aad203")) {                    Plotly.newPlot(                        "19b2525d-e970-4c1e-93d6-f9b414aad203",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[7.008578777313232,-24.054523468017578,-36.095272064208984,-23.684175491333008,-43.41594696044922,15.598664283752441,-27.813016891479492,-38.48366928100586,-17.512298583984375,3.1785411834716797,3.6038928031921387,-40.64223861694336,-41.93606948852539,5.811012268066406,23.135700225830078,-21.744922637939453,-43.41720199584961,-46.2606086730957,-37.89410400390625,6.001809597015381,47.49074172973633,-43.98033905029297,38.28439712524414,26.826961517333984,53.7520637512207,39.9819450378418,-47.39592361450195,14.125865936279297,-48.06440734863281,-37.12207794189453,11.345890998840332,14.549226760864258,-12.91830062866211,22.028865814208984,-42.73514938354492,-17.18494415283203,30.973209381103516,-37.06513214111328,-18.547319412231445,-5.167844772338867,-24.960947036743164,7.187079906463623,26.573711395263672,-35.96440505981445,21.063528060913086,48.44588088989258,51.156341552734375,22.147768020629883,5.0006794929504395,-25.78380012512207,14.973587989807129,46.71432876586914,-28.657546997070312,-19.505313873291016,-42.65959548950195,-42.294151306152344,-47.53120422363281,35.858558654785156,27.139421463012695,27.2122859954834,4.228511810302734,32.18904113769531,1.04933762550354,-7.76170539855957,40.29808044433594,31.60877227783203,31.709604263305664,2.060352087020874,49.35714340209961,-25.104049682617188,21.860904693603516,-26.800790786743164,4.583093166351318,-8.102614402770996,-8.595345497131348,16.66619873046875,-22.746763229370117,36.777015686035156,6.2659478187561035,34.90533447265625,-26.765623092651367,41.395606994628906,42.74964904785156,11.124159812927246,15.657936096191406,-13.856414794921875,-3.0119614601135254,-10.165874481201172,-16.937929153442383,-8.91871166229248,-42.55808639526367,-31.317340850830078,-25.41002655029297,41.99205780029297,-38.34614562988281,-19.28485679626465,-27.38967514038086,6.337403774261475,-27.628231048583984,52.89229965209961,-4.108450889587402,19.981334686279297,7.001791000366211,-24.644275665283203,-37.01203536987305,-22.84950065612793,-44.382781982421875,15.059080123901367,-27.85732650756836,-39.4627799987793,-17.191055297851562,0.9330818057060242,3.639061689376831,-41.3914680480957,-43.058876037597656,5.3771162033081055,20.34938621520996,-21.52403450012207,-42.48975372314453,-45.79829406738281,-36.54779815673828,5.978102684020996,-36.55473327636719,48.36206817626953,-43.650245666503906,38.61893081665039,26.4612979888916,53.67730712890625,39.3878173828125,-47.01836013793945,13.838720321655273,-47.61332321166992,-35.41006088256836,10.510077476501465,13.08297061920166,-13.616683959960938,20.18080711364746,-41.68890380859375,-17.791906356811523,30.843555450439453,-17.195392608642578,-3.9947521686553955,-24.541946411132812,8.140345573425293,26.541683197021484,-34.26411056518555,21.60512924194336,48.51700973510742,51.11979293823242,22.899015426635742,6.008301258087158,-28.44870376586914,16.985130310058594,46.87501525878906,-27.04266357421875,-18.223230361938477,-42.97654724121094,-42.37083435058594,-47.067848205566406,36.32228088378906,27.356966018676758,28.938819885253906,4.848236560821533,33.654563903808594,1.7372446060180664,-7.062557697296143,40.802249908447266,30.70293617248535,32.07614517211914,4.237256050109863,49.356834411621094,-25.334232330322266,21.412364959716797,-25.339879989624023,3.7 ...

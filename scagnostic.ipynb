# %% [markdown]
# <a href="https://colab.research.google.com/github/smbillah/ist526/blob/main/scagnostic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Essential Libraries

# %%
# python visualization libraries
import matplotlib.pyplot as plt
import matplotlib as mpl
# from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import plotly.express as px
# %matplotlib inline

import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as subplots

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Steps to High Dimensional Data Reduction

# %% [markdown]
# ## Loading data

# %% [markdown]
# ### Loading large dataset from Google Drive
# For large-scale datasets, it is not possible to load them from GitHub due to network traffics and latency. So, we need to load them from  Google Drive. Steps are shown below.
#
# **Make sure you to comment the following blocks if you are loading data from GitHub.

# %% [markdown]
# ### Mounting Google Drive

# %%
import os

# mount drive
from google.colab import drive
drive.mount('/content/drive')


# edit this path if needed
my_path = '/content/drive/My Drive/Colab Notebooks/'

# change to this path
os.chdir(my_path)

# verify present working directory. It should be identical to 'my_path'
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# ### Loading a .csv file from the 'data' folder in Google Drive

# %%
## assuming you have a 'data' folder in your 'My Drive/Colab Notebooks' folder, where a dataset (e.g., 'california_cities.csv') exists
## if you don't have the 'data' folder, create one

df = pd.read_csv('data/california_cities.csv')

display(df.head())
display(df.tail())
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 0         145.107        145.062           0.046                0.03
# 1          20.260         20.184           0.076                0.37
# 2          59.465         27.482          31.983               53.79
# 3          14.155          4.632           9.524               67.28
# 4          19.766         19.763           0.003                0.01
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 477          98.0              2933             1.531            1.531
# 478        2582.0              7765            10.053            9.980
# 479          59.0             64925            14.656           14.578
# 480        2618.0             51367            27.893           27.888
# 481        3369.0             20700            40.015           40.015
#
#      area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 477             0.000           3.966          3.966           0.000
# 478             0.073          26.036         25.847           0.188
# 479             0.078          37.959         37.758           0.201
# 480             0.005          72.244         72.231           0.013
# 481             0.000         103.639        103.639           0.000
#
#      area_water_percent
# 477                0.00
# 478                0.72
# 479                0.53
# 480                0.02
# 481                0.00

# %% [markdown]
# ### Preprocessing 1: data cleaning

# %%
# removing non-numeric, unwanted columns, and rows with missing data
df = df.drop(['Unnamed: 0', 'city', 'latd', 'longd'], axis = 1)

# removing rows with empty values
df.dropna(inplace=True)
display(df.head())
# Out:
#    elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# 0        875.0        2871.0             31765            56.027
# 1        281.0         922.0             20330             7.822
# 4        150.0         492.0             83089             7.632
# 5        127.0         417.0             47823             7.472
# 6       1332.0        4370.0              2827             2.449
#
#    area_land_sq_mi  area_water_sq_mi  area_total_km2  area_land_km2  \
# 0           56.009             0.018         145.107        145.062
# 1            7.793             0.029          20.260         20.184
# 4            7.631             0.001          19.766         19.763
# 5            7.472             0.000          19.352         19.352
# 6            2.435             0.014           6.342          6.306
#
#    area_water_km2  area_water_percent
# 0           0.046                0.03
# 1           0.076                0.37
# 4           0.003                0.01
# 5           0.000                0.00
# 6           0.036                0.57

# %% [markdown]
# # Interpret Scagnostic
# [library](https://github.com/haishiro/pyscagnostics)

# %% [markdown]
# ## Install library

# %%
# installation - run it once
# !pip install pyscagnostics
# Out:
# Collecting pyscagnostics
#   Downloading pyscagnostics-0.1.0a4-cp37-cp37m-manylinux2010_x86_64.whl (794 kB)
#      |████████████████████████████████| 794 kB 24.1 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from pyscagnostics) (1.21.6)
# Installing collected packages: pyscagnostics
# Successfully installed pyscagnostics-0.1.0a4

# %% [markdown]
# ## loading + clearning data

# %%
from pyscagnostics import scagnostics

## make sure all columns are numeric
display(df.head())
# Out:
#    elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0        2871.0             31765            56.027           56.009
# 1         922.0             20330             7.822            7.793
# 4         492.0             83089             7.632            7.631
# 5         417.0             47823             7.472            7.472
# 6        4370.0              2827             2.449            2.435
#
#    area_water_sq_mi  area_water_percent
# 0             0.018                0.03
# 1             0.029                0.37
# 4             0.001                0.01
# 5             0.000                0.00
# 6             0.014                0.57

# %% [markdown]
# ## Get scores for the data frame

# %%
# get sgagnostic scores from the library
results = scagnostics(df)

# %% [markdown]
# ## Convert scores to Scagnostic-format

# %%
# post-process results to make scagnostic

# create 9-attribute list
score_names = ['Outlying', 'Skewed', 'Clumpy', 'Sparse', 'Striated', 'Convex', 'Skinny', 'Stringy', 'Monotonic']

# add a new data source
data = {'score_names':score_names}

scores = None

# iterate over the reasults
for i, j, result in results:
  (measures, bins) = result  
  scores = measures
  
  ## debug
  print(i, j, measures)
  
  col_name = "{}_{}".format(i, j)  
  
  # copy scores
  row = []
  row.append(scores['Outlying'])
  row.append(scores['Skewed'])
  row.append(scores['Clumpy'])
  row.append(scores['Sparse'])
  row.append(scores['Striated'])
  row.append(scores['Convex'])
  row.append(scores['Skinny'])
  row.append(scores['Stringy'])
  row.append(scores['Monotonic'])

  # add current 'col_name' as key and 'row' as value to 'data'
  data[col_name] = row;
# end for
# Out:
# elevation_ft population_total {'Outlying': 0.9182228125792041, 'Skewed': 0.6652059378840942, 'Clumpy': 0.16267942583732056, 'Sparse': 0.024597391802917166, 'Striated': 0.14285714285714285, 'Convex': 0.42477481340329676, 'Skinny': 0.5929058907681155, 'Stringy': 0.4614012021036814, 'Monotonic': 0.011712367937244266}
# elevation_ft area_total_sq_mi {'Outlying': 0.6779274420779277, 'Skewed': 0.8290144725679989, 'Clumpy': 0.20574162679425836, 'Sparse': 0.03847275884004502, 'Striated': 0.09195402298850575, 'Convex': 0.3778435120265764, 'Skinny': 0.5264780976962471, 'Stringy': 0.4280187148601713, 'Monotonic': 0.02513322478329541}
# elevation_ft area_land_sq_mi {'Outlying': 0.7014973002555125, 'Skewed': 0.8078404077857002, 'Clumpy': 0.302158273381295, 'Sparse': 0.03900452938601761, 'Striated': 0.10112359550561797, 'Convex': 0.37831906384944025, 'Skinny': 0.5176015892030219, 'Stringy': 0.43404373177842565, 'Monotonic': 0.04222477530790023}
# elevation_ft area_water_sq_mi {'Outlying': 0.7999396130003398, 'Skewed': 0.8005553469194122, 'Clumpy': 0.02508783367277597, 'Sparse': 0.033295479399871306, 'Striated': 0.36666666666666664, 'Convex': 0.04673229038827894, 'Skinny': 0.7516358784352565, 'Stringy': 0.7471485545902556, 'Monotonic': 0.016950495199945487}
# elevation_ft area_water_percent {'Outlying': 0.6259859344883465, 'Skewed': 0.7850054801932214, 'Clumpy': 0.048141624705539836, 'Sparse': 0.03406568076626828, 'Striated': 0.2087912087912088, 'Convex': 0.05267422462825311, 'Skinny': 0.679693312055371, 'Stringy': 0.5380290370370371, 'Monotonic': 0.024013899273530707}
# population_total area_total_sq_mi {'Outlying': 1.2975435609909258, 'Skewed': 0.5489967503710934, 'Clumpy': 0.09691024940334127, 'Sparse': 0.021126638362223945, 'Striated': 0.0, 'Convex': 0.632308362351904, 'Skinny': 0.45670599299147685, 'Stringy': 0.3553964120370371, 'Monotonic': 0.5434464580363803}
# population_total area_land_sq_mi {'Outlying': 1.2536036754931068, 'Skewed': 0.6854846958135905, 'Clumpy': 0.09748682338521299, 'Sparse': 0.025330890826199493, 'Striated': 0.0, 'Convex': 0.7552785595111826, 'Skinny': 0.28022367923962743, 'Stringy': 0.31696093163035305, 'Monotonic': 0.5168424874993294}
# population_total area_water_sq_mi {'Outlying': 0.8838728496210597, 'Skewed': 0.826069070300225, 'Clumpy': 0.4988235294117647, 'Sparse': 0.040642593694088944, 'Striated': 0.08108108108108109, 'Convex': 0.41553459145331917, 'Skinny': 0.5773460677569814, 'Stringy': 0.5899768386425431, 'Monotonic': 0.01393174174164842}
# population_total area_water_percent {'Outlying': 0.9627724412920503, 'Skewed': 0.7689818609330639, 'Clumpy': 0.3990498812351544, 'Sparse': 0.03815413837408967, 'Striated': 0.1702127659574468, 'Convex': 0.23980121406787763, 'Skinny': 0.5369318495138469, 'Stringy': 0.5524031086161263, 'Monotonic': 0.0026955085561389774}
# area_total_sq_mi area_land_sq_mi {'Outlying': 1.2376564837412611, 'Skewed': 0.5633960742789834, 'Clumpy': 0.5518867924528302, 'Sparse': 0.02286113303809152, 'Striated': 0.25925925925925924, 'Convex': 0.5288034418789042, 'Skinny': 0.5859651327669323, 'Stringy': 0.5477084898572503, 'Monotonic': 0.9682467402143292}
# area_total_sq_mi area_water_sq_mi {'Outlying': 0.7288795077129513, 'Skewed': 0.704149393414128, 'Clumpy': 0.5639810426540285, 'Sparse': 0.03274090105547851, 'Striated': 0.05555555555555555, 'Convex': 0.27668765035173, 'Skinny': 0.4793877901895216, 'Stringy': 0.45199793728854065, 'Monotonic': 0.04525235542363963}
# area_total_sq_mi area_water_percent {'Outlying': 0.7701035336224077, 'Skewed': 0.7831137670690373, 'Clumpy': 0.40669856459330145, 'Sparse': 0.036477553706106634, 'Striated': 0.027777777777777776, 'Convex': 0.22156898366438846, 'Skinny': 0.6480584864770147, 'Stringy': 0.5055190647534558, 'Monotonic': 0.0017708920811375464}
# area_land_sq_mi area_water_sq_mi {'Outlying': 0.7341671727222608, 'Skewed': 0.7924173106253154, 'Clumpy': 0.5402843601895735, 'Sparse': 0.033203692927797714, 'Striated': 0.1111111111111111, 'Convex': 0.269941805525166, 'Skinny': 0.6152306298029198, 'Stringy': 0.45199793728854065, 'Monotonic': 0.0008125260151141453}
# area_land_sq_mi area_water_percent {'Outlying': 0.7349406031151586, 'Skewed': 0.7883289935265113, 'Clumpy': 0.3818615751789976, 'Sparse': 0.03406568076626828, 'Striated': 0.0958904109589041, 'Convex': 0.1722076132815518, 'Skinny': 0.6748665099281679, 'Stringy': 0.5120000000000001, 'Monotonic': 0.008454491106642939}
# area_water_sq_mi area_water_percent {'Outlying': 0.2735258152168063, 'Skewed': 0.8391435801001006, 'Clumpy': 0.2447058823529412, 'Sparse': 0.11269233172317793, 'Striated': 0.05172413793103448, 'Convex': 0.3210307150150883, 'Skinny': 0.6094044318214007, 'Stringy': 0.34972530052592044, 'Monotonic': 0.6578629678762136}

# %% [markdown]
# ## Create a dataframe for scagnostic visualization

# %%
# convert 'data' to data-frame named 'df_scagnostic'
df_scagnostic = pd.DataFrame.from_dict(data);

# make the first column 'score_names' to index
df_scagnostic.set_index('score_names', inplace=True)

# check out the dataframe
display(df_scagnostic.head(9))
# Out:
#              elevation_ft_population_total  elevation_ft_area_total_sq_mi  \
# score_names
# Outlying                          0.918223                       0.677927
# Skewed                            0.665206                       0.829014
# Clumpy                            0.162679                       0.205742
# Sparse                            0.024597                       0.038473
# Striated                          0.142857                       0.091954
# Convex                            0.424775                       0.377844
# Skinny                            0.592906                       0.526478
# Stringy                           0.461401                       0.428019
# Monotonic                         0.011712                       0.025133
#
#              elevation_ft_area_land_sq_mi  elevation_ft_area_water_sq_mi  \
# score_names
# Outlying                         0.701497                       0.799940
# Skewed                           0.807840                       0.800555
# Clumpy                           0.302158                       0.025088
# Sparse                           0.039005                       0.033295
# Striated                         0.101124                       0.366667
# Convex                           0.378319                       0.046732
# Skinny                           0.517602                       0.751636
# Stringy                          0.434044                       0.747149
# Monotonic                        0.042225                       0.016950
#
#              elevation_ft_area_water_percent  \
# score_names
# Outlying                            0.625986
# Skewed                              0.785005
# Clumpy                              0.048142
# Sparse                              0.034066
# Striated                            0.208791
# Convex                              0.052674
# Skinny                              0.679693
# Stringy                             0.538029
# Monotonic                           0.024014
#
#              population_total_area_total_sq_mi  \
# score_names
# Outlying                              1.297544
# Skewed                                0.548997
# Clumpy                                0.096910
# Sparse                                0.021127
# Striated                              0.000000
# Convex                                0.632308
# Skinny                                0.456706
# Stringy                               0.355396
# Monotonic                             0.543446
#
#              population_total_area_land_sq_mi  \
# score_names
# Outlying                             1.253604
# Skewed                               0.685485
# Clumpy                               0.097487
# Sparse                               0.025331
# Striated                             0.000000
# Convex                               0.755279
# Skinny                               0.280224
# Stringy                              0.316961
# Monotonic                            0.516842
#
#              population_total_area_water_sq_mi  \
# score_names
# Outlying                              0.883873
# Skewed                                0.826069
# Clumpy                                0.498824
# Sparse                                0.040643
# Striated                              0.081081
# Convex                                0.415535
# Skinny                                0.577346
# Stringy                               0.589977
# Monotonic                             0.013932
#
#              population_total_area_water_percent  \
# score_names
# Outlying                                0.962772
# Skewed                                  0.768982
# Clumpy                                  0.399050
# Sparse                                  0.038154
# Striated                                0.170213
# Convex                                  0.239801
# Skinny                                  0.536932
# Stringy                                 0.552403
# Monotonic                               0.002696
#
#              area_total_sq_mi_area_land_sq_mi  \
# score_names
# Outlying                             1.237656
# Skewed                               0.563396
# Clumpy                               0.551887
# Sparse                               0.022861
# Striated                             0.259259
# Convex                               0.528803
# Skinny                               0.585965
# Stringy                              0.547708
# Monotonic                            0.968247
#
#              area_total_sq_mi_area_water_sq_mi  \
# score_names
# Outlying                              0.728880
# Skewed                                0.704149
# Clumpy                                0.563981
# Sparse                                0.032741
# Striated                              0.055556
# Convex                                0.276688
# Skinny                                0.479388
# Stringy                               0.451998
# Monotonic                             0.045252
#
#              area_total_sq_mi_area_water_percent  \
# score_names
# Outlying                                0.770104
# Skewed                                  0.783114
# Clumpy                                  0.406699
# Sparse                                  0.036478
# Striated                                0.027778
# Convex                                  0.221569
# Skinny                                  0.648058
# Stringy                                 0.505519
# Monotonic                               0.001771
#
#              area_land_sq_mi_area_water_sq_mi  \
# score_names
# Outlying                             0.734167
# Skewed                               0.792417
# Clumpy                               0.540284
# Sparse                               0.033204
# Striated                             0.111111
# Convex                               0.269942
# Skinny                               0.615231
# Stringy                              0.451998
# Monotonic                            0.000813
#
#              area_land_sq_mi_area_water_percent  \
# score_names
# Outlying                               0.734941
# Skewed                                 0.788329
# Clumpy                                 0.381862
# Sparse                                 0.034066
# Striated                               0.095890
# Convex                                 0.172208
# Skinny                                 0.674867
# Stringy                                0.512000
# Monotonic                              0.008454
#
#              area_water_sq_mi_area_water_percent
# score_names
# Outlying                                0.273526
# Skewed                                  0.839144
# Clumpy                                  0.244706
# Sparse                                  0.112692
# Striated                                0.051724
# Convex                                  0.321031
# Skinny                                  0.609404
# Stringy                                 0.349725
# Monotonic                               0.657863

# %% [markdown]
# ## Finally, visualize scagnostic

# %%
# now that our dataframe is in perfect condition, visualiza it with plotly
import plotly.express as px

fig = px.imshow(df_scagnostic, text_auto=True, aspect="auto")
fig.update_xaxes(side="top")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a12a0c5b-8e8d-44fd-ae91-d76f21448b87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a12a0c5b-8e8d-44fd-ae91-d76f21448b87")) {                    Plotly.newPlot(                        "a12a0c5b-8e8d-44fd-ae91-d76f21448b87",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["elevation_ft_population_total","elevation_ft_area_total_sq_mi","elevation_ft_area_land_sq_mi","elevation_ft_area_water_sq_mi","elevation_ft_area_water_percent","population_total_area_total_sq_mi","population_total_area_land_sq_mi","population_total_area_water_sq_mi","population_total_area_water_percent","area_total_sq_mi_area_land_sq_mi","area_total_sq_mi_area_water_sq_mi","area_total_sq_mi_area_water_percent","area_land_sq_mi_area_water_sq_mi","area_land_sq_mi_area_water_percent","area_water_sq_mi_area_water_percent"],"y":["Outlying","Skewed","Clumpy","Sparse","Striated","Convex","Skinny","Stringy","Monotonic"],"z":[[0.9182228125792041,0.6779274420779277,0.7014973002555125,0.7999396130003398,0.6259859344883465,1.2975435609909258,1.2536036754931068,0.8838728496210597,0.9627724412920503,1.2376564837412611,0.7288795077129513,0.7701035336224077,0.7341671727222608,0.7349406031151586,0.2735258152168063],[0.6652059378840942,0.8290144725679989,0.8078404077857002,0.8005553469194122,0.7850054801932214,0.5489967503710934,0.6854846958135905,0.826069070300225,0.7689818609330639,0.5633960742789834,0.704149393414128,0.7831137670690373,0.7924173106253154,0.7883289935265113,0.8391435801001006],[0.16267942583732056,0.20574162679425836,0.302158273381295,0.02508783367277597,0.048141624705539836,0.09691024940334127,0.09748682338521299,0.4988235294117647,0.3990498812351544,0.5518867924528302,0.5639810426540285,0.40669856459330145,0.5402843601895735,0.3818615751789976,0.2447058823529412],[0.024597391802917166,0.03847275884004502,0.03900452938601761,0.033295479399871306,0.03406568076626828,0.021126638362223945,0.025330890826199493,0.040642593694088944,0.03815413837408967,0.02286113303809152,0.03274090105547851,0.036477553706106634,0.033203692927797714,0.03406568076626828,0.11269233172317793],[0.14285714285714285,0.09195402298850575,0.10112359550561797,0.36666666666666664,0.2087912087912088,0.0,0.0,0.08108108108108109,0.1702127659574468,0.25925925925925924,0.05555555555555555,0.027777777777777776,0.1111111111111111,0.0958904109589041,0.05172413793103448],[0.42477481340329676,0.3778435120265764,0.37831906384944025,0.04673229038827894,0.05267422462825311,0.632308362351904,0.7552785595111826,0.41553459145331917,0.23980121406787763,0.5288034418789042,0.27668765035173,0.22156898366438846,0.269941805525166,0.1722076132815518,0.3210307150150883],[0.5929058907681155,0.5264780976962471,0.5176015892030219,0.7516358784352565,0.679693312055371,0.45670599299147685,0.28022367923962743,0.5773460677569814,0.5369318495138469,0.5859651327669323,0.4793877901895216,0.6480584864770147,0.6152306298029198,0.6748665099281679,0.6094044318214007],[0.4614012021036814,0.4280187148601713,0.43404373177842565,0.7471485545902556,0.5380290370370371,0.3553964120370371,0.31696093163035305,0.5899768386425431,0.5524031086161263,0.5477084898572503,0.45199793728854065,0.5055190647534558,0.45199793728854065,0.5120000000000001,0.34972530052592044],[0.011712367937244266,0.02513322478329541,0.04222477530790023,0.016950495199945487,0.024013899273530707,0.5434464580363803,0.5168424874993294,0.01393174174164842,0.0026955085561389774,0.9682467402143292,0.04525235542363963,0.0017708920811375464,0.0008125260151141453,0.008454491106642939,0.6578629678762136]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>score_names: %{y}<br>color: %{z}<extra></extra>"}],                        ...

# %%
import plotly.express as px

# select features/columns 
# features = ['petal.length', 'sepal.length', 'petal.width', 'sepal.width']

fig = px.scatter_matrix(
    df,
    # dimensions=features,
    # color="variety"
)

## adjust height and width of subplot
fig.update_layout(
  autosize=False,
  width=1200,
  height=1200,
)

fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="392360cf-5d48-4ce6-8879-431c9c785bba" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("392360cf-5d48-4ce6-8879-431c9c785bba")) {                    Plotly.newPlot(                        "392360cf-5d48-4ce6-8879-431c9c785bba",                        [{"dimensions":[{"axis":{"matches":true},"label":"elevation_ft","values":[2871.0,922.0,492.0,417.0,4370.0,919.0,46.0,157.0,430.0,1378.0,43.0,2946.0,482.0,118.0,52.0,449.0,879.0,59.0,151.0,1227.0,30.0,807.0,610.0,374.0,2349.0,2178.0,2612.0,141.0,71.0,121.0,43.0,36.0,26.0,660.0,259.0,6752.0,98.0,131.0,272.0,676.0,-112.0,361.0,108.0,358.0,75.0,607.0,39.0,5.0,2405.0,2392.0,348.0,177.0,197.0,1385.0,13.0,52.0,33.0,27.0,328.0,92.0,34.0,245.0,728.0,1070.0,240.0,69.0,164.0,394.0,1417.0,361.0,-66.0,673.0,2425.0,121.0,1004.0,52.0,141.0,69.0,85.3,207.0,276.0,678.0,20.0,39.0,98.0,112.0,558.0,121.0,95.0,236.0,39.0,187.0,144.0,358.0,52.0,315.0,112.0,82.0,1076.0,696.0,345.0,62.0,4245.0,118.0,118.0,512.0,2280.0,20.0,436.0,-39.0,45.0,299.0,115.0,23.0,82.0,118.0,646.0,2936.0,390.0,115.0,13.0,358.0,56.0,456.0,151.0,220.0,1237.0,2762.0,66.0,7.0,33.0,308.0,218.0,164.0,47.0,49.0,89.0,200.0,522.0,774.0,135.0,1063.0,2411.0,289.0,62.0,85.0,98.0,72.0,249.0,33.0,72.0,105.0,1594.0,79.0,26.0,3186.0,1076.0,1309.0,322.0,289.0,-10.0,125.0,39.0,171.0,374.0,69.0,-59.0,89.0,-13.0,322.0,131.0,299.0,45.0,469.0,10.0,1217.0,220.0,335.0,302.0,320.0,20.0,371.0,397.0,381.0,299.0,738.0,1306.0,400.0,1355.0,46.0,528.0,194.0,2359.0,46.0,351.0,20.0,1060.0,59.0,440.0,230.0,167.0,387.0,131.0,50.0,1165.0,95.0,105.0,404.0,23.0,292.0,2.0,118.0,344.0,4951.0,92.0,271.0,105.0,7880.0,67.0,38.0,883.0,43.0,23.0,62.0,151.0,354.0,174.0,1424.0,72.0,171.0,16.0,448.0,89.0,571.0,2539.0,1066.0,200.0,26.0,384.0,515.0,1631.0,350.0,62.0,105.0,3606.0,1096.0,69.0,495.0,2477.0,89.0,640.0,92.0,30.0,157.0,20.0,66.0,745.0,925.0,195.0,423.0,495.0,259.0,167.0,52.0,82.0,151.0,2657.0,220.0,440.0,30.0,210.0,1778.0,69.0,344.0,863.0,102.0,1453.0,30.0,164.0,23.0,56.0,26.0,272.0,52.0,1083.0,118.0,850.0,459.0,12.0,4856.0,459.0,515.0,89.0,1207.0,220.0,775.0,305.0,495.0,1358.0,20.0,348.0,1257.0,46.0,2290.0,161.0,20.0,69.0,141.0,860.0,249.0,105.0,1276.0,469.0,318.0,164.0,36.0,30.0,52.0,46.0,1974.0,16.0,250.0,72.0,3.0,1070.0,420.0,1565.0,174.0,217.0,96.0,56.0,233.0,564.0,43.0,52.0,43.0,480.0,115.0,49.0,75.0,1207.0,36.0,135.0,220.0,279.0,164.0,345.0,13.0,561.0,13.0,33.0,82.0,308.0,348.0,810.0,827.0,148.0,768.0,72.0,190.0,505.0,85.0,1785.0,249.0,120.0,6237.0,659.0,13.0,66.0,253.0,13.0,7.0,128.0,4186.0,1188.0,955.0,3970.0,210.0,1019.0,400.0,886.0,13.0,89.0,52.0,174.0,5817.0,289.0,4035.0,102.0,141.0,1991.0,639.0,1328.0,174.0,60.0,203.0,2726.0,341.0,331.0,325.0,561.0,328.0,171.0,29.0,3425.0,362.0,282.0,880.0,39.0,20.0,92.0,367.0,1270.0,82.0,1391.0,138.0,118.0,131.0,440.0,69.0,384.0,270.0,98.0,2582.0,59.0,2618.0,3369.0]},{"axis":{"matches":true},"label":"population_total","values":[31765,20330,83089,47823,2827,185,19454,336000,9932,3836,107100,69135,56364,17716,16522,19304,28310,6914,28168,13330,3728,13239,46361,75390,29603,22639,36877,35477,76616,42072,25835,2068,26997,112580,34290,5019,1707,1253,20817,1048,24953,39282,4282,4828,80530,103340,28806,23058,14120,7879,5155,65201,39349,10561,9918,105328,13040,91714,51200,45417,49041,86187,77983,75655,18720,243916,83301,10897,15250,101314,40704,13380,1963,1792,52154,5971,12823,96455,122067,25515,17382,158391,24697,9253,109960,7310,47796,23805,38883,58302,47802,101123,33351,42039,65622,53819,4161,1624,25938,55544,21453,18351,939,4950,111772,21321,1650,28155,99478,42598,153015,113475,16654,10080,59518,7266,143911,737,10334,7441,108321,10588,1371,15002,7549,72203,201812,839,11926,30567,55313,5570,220000,135161,23647,58829,170883,48821,1960 ...

# %% [markdown]
# Interpretation: ??
